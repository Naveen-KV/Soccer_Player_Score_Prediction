# %% [markdown]
# # Soccer Player Score Prediction

# %%
# IMPORT REQUIRED LIBRARIES

import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

import sqlite3

# %%
# READ DATASET FROM SQLITE3 DATABASE

cnx = sqlite3.connect("/content/drive/MyDrive/Colab Notebooks/Soccer_Player_Score_Prediction/database.sqlite")
df = pd.read_sql_query("SELECT * FROM Player_Attributes",cnx)

# %%
# Make a Master copy of dataset
df_copy = df.copy()

# %%
pd.pandas.set_option("display.max_columns", None)
df.head()
# Out:
#    id  player_fifa_api_id  player_api_id                 date  overall_rating  \
# 0   1              218353         505942  2016-02-18 00:00:00            67.0
# 1   2              218353         505942  2015-11-19 00:00:00            67.0
# 2   3              218353         505942  2015-09-21 00:00:00            62.0
# 3   4              218353         505942  2015-03-20 00:00:00            61.0
# 4   5              218353         505942  2007-02-22 00:00:00            61.0
#
#    potential preferred_foot attacking_work_rate defensive_work_rate  crossing  \
# 0       71.0          right              medium              medium      49.0
# 1       71.0          right              medium              medium      49.0
# 2       66.0          right              medium              medium      49.0
# 3       65.0          right              medium              medium      48.0
# 4       65.0          right              medium              medium      48.0
#
# ...

# %% [markdown]
# Check the various attributes of data like shape (rows and cols), Columns, datatypes

# %%
df.shape
# Out:
# (183978, 42)

# %%
# REMOVE DUPLICATE VALUES IF ANY

df.drop_duplicates(inplace = True)

# %%
df.shape
# Out:
# (183978, 42)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 183978 entries, 0 to 183977
# Data columns (total 42 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   id                   183978 non-null  int64
#  1   player_fifa_api_id   183978 non-null  int64
#  2   player_api_id        183978 non-null  int64
#  3   date                 183978 non-null  object
#  4   overall_rating       183142 non-null  float64
#  5   potential            183142 non-null  float64
#  6   preferred_foot       183142 non-null  object
#  7   attacking_work_rate  180748 non-null  object
#  8   defensive_work_rate  183142 non-null  object
#  9   crossing             183142 non-null  float64
#  10  finishing            183142 non-null  float64
#  11  heading_accuracy     183142 non-null  float64
#  12  short_passing        183142 non-null  float64
#  13  volleys              181265 non-null  float64
# ...

# %% [markdown]
# Check for any null values

# %%
df.isnull().sum()
# Out:
# id                        0
# player_fifa_api_id        0
# player_api_id             0
# date                      0
# overall_rating          836
# potential               836
# preferred_foot          836
# attacking_work_rate    3230
# defensive_work_rate     836
# crossing                836
# finishing               836
# heading_accuracy        836
# short_passing           836
# volleys                2713
# dribbling               836
# curve                  2713
# free_kick_accuracy      836
# long_passing            836
# ball_control            836
# acceleration            836
# sprint_speed            836
# agility                2713
# reactions               836
# balance                2713
# shot_power              836
# jumping                2713
# stamina                 836
# strength                836
# long_shots              836
# aggression              836
# interceptions           836
# positioning             836
# vision                 2713
# ...

# %%
sns.heatmap(df.isnull(),yticklabels = False)

# %% [markdown]
# It looks like many columns have 836 null values and the records with null values are same for those columns. We will verify it by checking the records with null values.

# %%
df[df["overall_rating"].isnull()].head(20)
# Out:
#         id  player_fifa_api_id  player_api_id                 date  \
# 483    484               33022          31684  2007-02-22 00:00:00
# 983    984              111085          29904  2007-02-22 00:00:00
# 1752  1753              165740          24159  2007-02-22 00:00:00
# 2089  2090              176941          31916  2007-02-22 00:00:00
# 2482  2483              177615          37249  2007-02-22 00:00:00
# 2498  2499              177713          40012  2007-02-22 00:00:00
# 2540  2541                2115          38612  2007-02-22 00:00:00
# 3283  3284              152769          41109  2007-02-22 00:00:00
# 4006  4007              172176          23163  2007-02-22 00:00:00
# 4202  4203              140307          32547  2007-02-22 00:00:00
# 4593  4594              110375          45605  2007-02-22 00:00:00
# 4801  4802              178087          41168  2007-02-22 00:00:00
# 4998  4999              123617          39743  2007-02-22 00:00:00
# ...

# %%
df[df["overall_rating"].isnull()].tail(20)
# Out:
#             id  player_fifa_api_id  player_api_id                 date  \
# 178247  178248              167993          33439  2007-02-22 00:00:00
# 178612  178613                9978          37577  2007-02-22 00:00:00
# 178888  178889              175787          22544  2007-02-22 00:00:00
# 179003  179004               54051          38831  2007-02-22 00:00:00
# 179079  179080              135472          39963  2007-02-22 00:00:00
# 179776  179777                6647          38835  2007-02-22 00:00:00
# 180062  180063              164010          35463  2007-02-22 00:00:00
# 180245  180246              176285          35110  2007-02-22 00:00:00
# 180465  180466              139443          31085  2007-02-22 00:00:00
# 180783  180784              124871          30936  2007-02-22 00:00:00
# 180806  180807              173073          26409  2007-02-22 00:00:00
# 180905  180906              164471          37845  2007-02-22 00:00:00
# ...

# %% [markdown]
# Delete rows where 'overall_rating' is null as almost all other columns in those rows are also null

# %%
df.dropna(subset = ["overall_rating"], inplace = True)

# %% [markdown]
# Now, let us check percentage of null values present in each feature

# %%
features_with_na = [feature for feature in df.columns if df[feature].isnull().sum()>0]

for feature in features_with_na:
    print(feature, ": {}%".format(np.round(df[feature].isnull().mean(),3)))
# Out:
# attacking_work_rate : 0.013%
# volleys : 0.01%
# curve : 0.01%
# agility : 0.01%
# balance : 0.01%
# jumping : 0.01%
# vision : 0.01%
# sliding_tackle : 0.01%

# %% [markdown]
# We will drop the records as only very few missing values are there

# %%
df.dropna(inplace = True, axis = 0)

# %%
missing = pd.DataFrame((df.isnull().sum())*100/df.shape[0]).reset_index()
plt.figure(figsize=(16,5))
ax = sns.pointplot('index',0,data=missing)
plt.xticks(rotation =90,fontsize =7)
plt.title("Percentage of Missing values")
plt.ylabel("PERCENTAGE")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# We will remove 'id', player_fifa_api_id', 'player_api_id' and 'date' columns as these are not significant in predicting the score

# %%
df.drop(["id", "player_fifa_api_id","player_api_id", "date"], axis = 1, inplace = True)

# %%
df.columns
# Out:
# Index(['overall_rating', 'potential', 'preferred_foot', 'attacking_work_rate',
#        'defensive_work_rate', 'crossing', 'finishing', 'heading_accuracy',
#        'short_passing', 'volleys', 'dribbling', 'curve', 'free_kick_accuracy',
#        'long_passing', 'ball_control', 'acceleration', 'sprint_speed',
#        'agility', 'reactions', 'balance', 'shot_power', 'jumping', 'stamina',
#        'strength', 'long_shots', 'aggression', 'interceptions', 'positioning',
#        'vision', 'penalties', 'marking', 'standing_tackle', 'sliding_tackle',
#        'gk_diving', 'gk_handling', 'gk_kicking', 'gk_positioning',
#        'gk_reflexes'],
#       dtype='object')

# %% [markdown]
# Numerical Features

# %%
feature_numeric = [feature for feature in df.columns if df[feature].dtypes != "O"]

print(len(feature_numeric))
# Out:
# 35

# %%
# visualise the numerical variables
df_numeric = df[feature_numeric].copy()
df_numeric.head()
# Out:
#    overall_rating  potential  crossing  finishing  heading_accuracy  \
# 0            67.0       71.0      49.0       44.0              71.0
# 1            67.0       71.0      49.0       44.0              71.0
# 2            62.0       66.0      49.0       44.0              71.0
# 3            61.0       65.0      48.0       43.0              70.0
# 4            61.0       65.0      48.0       43.0              70.0
#
#    short_passing  volleys  dribbling  curve  free_kick_accuracy  long_passing  \
# 0           61.0     44.0       51.0   45.0                39.0          64.0
# 1           61.0     44.0       51.0   45.0                39.0          64.0
# 2           61.0     44.0       51.0   45.0                39.0          64.0
# 3           60.0     43.0       50.0   44.0                38.0          63.0
# 4           60.0     43.0       50.0   44.0                38.0          63.0
#
#    ball_control  acceleration  sprint_speed  agility  reactions  balance  \
# ...

# %%
df_numeric.describe()
# Out:
#        overall_rating      potential       crossing      finishing  \
# count   180354.000000  180354.000000  180354.000000  180354.000000
# mean        68.635317      73.479457      55.142071      49.962136
# std          7.027950       6.581963      17.247231      19.041760
# min         33.000000      39.000000       1.000000       1.000000
# 25%         64.000000      69.000000      45.000000      34.000000
# 50%         69.000000      74.000000      59.000000      53.000000
# 75%         73.000000      78.000000      68.000000      65.000000
# max         94.000000      97.000000      95.000000      97.000000
#
#        heading_accuracy  short_passing        volleys      dribbling  \
# count     180354.000000  180354.000000  180354.000000  180354.000000
# mean          57.263476      62.486726      49.488927      59.265755
# std           16.478716      14.172493      18.252319      17.741351
# min            1.000000       3.000000       1.000000       1.000000
# ...

# %%
## Lets analyse the continuous values by creating histograms to understand the distribution

for feature in feature_numeric:
    data=df.copy()
    data[feature].hist(bins=25)
    plt.xlabel(feature)
    plt.ylabel("Count")
    plt.title(feature)
    plt.show()

# %% [markdown]
# We can see that while some features are kind of normally distributed, some  features like standing_tackle and sliding_tackle have bimodal distribution and gk_features have most of the values less than 20. This is logical as players playing at different positions need to be good at different skills.

# %%
categorical_features=[feature for feature in df.columns if df[feature].dtypes=='O']
df[categorical_features].head()
# Out:
#   preferred_foot attacking_work_rate defensive_work_rate
# 0          right              medium              medium
# 1          right              medium              medium
# 2          right              medium              medium
# 3          right              medium              medium
# 4          right              medium              medium

# %%
# Let us check how many labels are there for the categorical features
for feature in categorical_features:
    print('The feature is {} and number of categories are {}'.format(feature,len(df[feature].unique())))
# Out:
# The feature is preferred_foot and number of categories are 2
# The feature is attacking_work_rate and number of categories are 8
# The feature is defensive_work_rate and number of categories are 18

# %%
# We will combine all labels whoose count is less than 10% of the length of dataset as a single label "Rare_var"

for feature in categorical_features:
    temp=df.groupby(feature)['overall_rating'].count()/len(df)
    temp_df=temp[temp>0.01].index
    df[feature]=np.where(df[feature].isin(temp_df),df[feature],'Rare_var')

# %%
# Now, we will do label encoding for the categorical features

for feature in categorical_features:
    labels_ordered=df.groupby([feature])['overall_rating'].mean().sort_values().index
    labels_ordered={k:i for i,k in enumerate(labels_ordered,0)}
    df[feature]=df[feature].map(labels_ordered)

# %%
df.head(10)
# Out:
#    overall_rating  potential  preferred_foot  attacking_work_rate  \
# 0            67.0       71.0               0                    2
# 1            67.0       71.0               0                    2
# 2            62.0       66.0               0                    2
# 3            61.0       65.0               0                    2
# 4            61.0       65.0               0                    2
# 5            74.0       76.0               1                    4
# 6            74.0       76.0               1                    4
# 7            73.0       75.0               1                    4
# 8            73.0       75.0               1                    4
# 9            73.0       75.0               1                    4
#
#    defensive_work_rate  crossing  finishing  heading_accuracy  short_passing  \
# 0                    1      49.0       44.0              71.0           61.0
# 1                    1      49.0       44.0              71.0           61.0
# ...

# %%
## Capture the dependent feature
Y =df[['overall_rating']]

## drop dependent feature from dataset
X =df.drop(['overall_rating'],axis=1)

# %%
# Now, let us  split the dataset to trin and test data

from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size = 0.2, random_state = 0)

# %%
# Now, let us scale the features using MinMaxScaler for the training data


from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
scaler.fit(x_train)
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
x_scale_transform = pd.DataFrame(scaler.transform(x_train), columns=feature_scale)

# %%
x_scale_transform.head()
# Out:
#    potential  preferred_foot  attacking_work_rate  defensive_work_rate  \
# 0   0.775862             0.0                  0.5             0.333333
# 1   0.637931             0.0                  1.0             0.333333
# 2   0.534483             0.0                  0.5             0.333333
# 3   0.586207             0.0                  0.5             0.333333
# 4   0.655172             0.0                  0.5             0.333333
#
#    crossing  finishing  heading_accuracy  short_passing   volleys  dribbling  \
# 0  0.702128   0.437500          0.690722       0.808511  0.771739   0.656250
# 1  0.648936   0.406250          0.597938       0.648936  0.326087   0.656250
# 2  0.414894   0.302083          0.680412       0.563830  0.369565   0.427083
# 3  0.659574   0.364583          0.649485       0.691489  0.315217   0.656250
# 4  0.436170   0.291667          0.680412       0.776596  0.391304   0.666667
#
# ...

# %%
x_scale_transform_test = pd.DataFrame(scaler.transform(x_test), columns=feature_scale)

# %%
x_scale_transform_test.head()
# Out:
#    potential  preferred_foot  attacking_work_rate  defensive_work_rate  \
# 0   0.637931             1.0                  1.0             1.000000
# 1   0.637931             0.0                  0.5             0.333333
# 2   0.568966             0.0                  0.5             0.333333
# 3   0.568966             0.0                  0.5             0.333333
# 4   0.689655             0.0                  0.5             0.333333
#
#    crossing  finishing  heading_accuracy  short_passing   volleys  dribbling  \
# 0  0.680851   0.604167          0.680412       0.808511  0.826087   0.750000
# 1  0.489362   0.625000          0.587629       0.819149  0.663043   0.791667
# 2  0.691489   0.604167          0.556701       0.734043  0.630435   0.687500
# 3  0.478723   0.333333          0.773196       0.648936  0.347826   0.385417
# 4  0.808511   0.677083          0.536082       0.808511  0.750000   0.802083
#
# ...

# %%
# transform the train and test set, and add on the Id and SalePrice variables
data = pd.concat([df[["overall_rating"]].reset_index(drop=True),
                    pd.DataFrame(scaler.transform(df[feature_scale]), )],
                    axis=1)

# %%
data.head()

# %% [markdown]
# ##  Feature Selection using Lasso

# %%
from sklearn.linear_model import Lasso
from sklearn.feature_selection import SelectFromModel

# %%
feature_sel_model = SelectFromModel(Lasso(alpha=0.005, random_state=0)) # remember to set the seed, the random state in this function
feature_sel_model.fit(x_scale_transform, y_train)
# Out:
# SelectFromModel(estimator=Lasso(alpha=0.005, copy_X=True, fit_intercept=True,
#                                 max_iter=1000, normalize=False, positive=False,
#                                 precompute=False, random_state=0,
#                                 selection='cyclic', tol=0.0001,
#                                 warm_start=False),
#                 max_features=None, norm_order=1, prefit=False, threshold=None)

# %%
# let's print the number of total and selected features

# this is how we can make a list of the selected features
selected_feat = x_scale_transform.columns[(feature_sel_model.get_support())]

# let's print some stats
print('total features: {}'.format((x_scale_transform.shape[1])))
print('selected features: {}'.format(len(selected_feat)))
print('features with coefficients shrank to zero: {}'.format(np.sum(feature_sel_model.estimator_.coef_ == 0)))
# Out:
# total features: 37
# selected features: 27
# features with coefficients shrank to zero: 10

# %%
selected_feat
# Out:
# Index(['potential', 'attacking_work_rate', 'defensive_work_rate', 'crossing',
#        'finishing', 'heading_accuracy', 'short_passing', 'curve',
#        'free_kick_accuracy', 'long_passing', 'ball_control', 'sprint_speed',
#        'reactions', 'shot_power', 'jumping', 'strength', 'aggression',
#        'interceptions', 'positioning', 'penalties', 'marking',
#        'sliding_tackle', 'gk_diving', 'gk_handling', 'gk_kicking',
#        'gk_positioning', 'gk_reflexes'],
#       dtype='object')

# %%
X_train=x_scale_transform[selected_feat]

# %%
from sklearn.linear_model import LinearRegression
import sklearn.metrics

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
X_test= pd.DataFrame(feature_sel_model.transform(x_scale_transform_test),columns=selected_feat)

# %%
y_predict = lr.predict(X_test)

# %%
sns.distplot(y_test-y_predict)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.scatter(y_test,y_predict)

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, y_predict))
print('MSE:', metrics.mean_squared_error(y_test, y_predict))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_predict)))
# Out:
# MAE: 2.1338699282428766
# MSE: 7.733231714984905
# RMSE: 2.7808688777043957

# %%
metrics.r2_score(y_test, y_predict)
# Out:
# 0.841607831946822

# %%
import pickle

# %%
filename = 'model_LR.sav'
pickle.dump(lr, open(filename, 'wb'))
